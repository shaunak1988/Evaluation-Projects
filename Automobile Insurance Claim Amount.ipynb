# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Auto_Insurance_Claims_amount.csv',parse_dates=['Effective To Date'])
df
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0     BU79786      US         KS    Kansas    276.351928       No     Basic
# 1     QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2     AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3     WW63253      US         MO  Missouri    764.586183       No     Basic
# 4     HB64268      US         KS    Kansas    281.369258       No     Basic
# ...       ...     ...        ...       ...           ...      ...       ...
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
# ...

# %%
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor        2011-02-24         Employed  ...
# 1  Bachelor        2011-01-31       Unemployed  ...
# 2  Bachelor        2011-02-19         Employed  ...
# 3  Bachelor        2011-01-20       Unemployed  ...
# 4  Bachelor        2011-02-03         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
df.shape
# Out:
# (9134, 26)

# %%
df.dtypes
# Out:
# Customer                                 object
# Country                                  object
# State Code                               object
# State                                    object
# Claim Amount                            float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# EmploymentStatus                         object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                   int64
# Months Since Policy Inception             int64
# Number of Open Complaints                 int64
# Number of Policies                        int64
# Policy Type                              object
# ...

# %%
# Customer names, Country(United States) and State Code are of little importance

# let's drop them
## Removing the unncessary columns

df.drop(['Customer','Country','State Code'],axis=1,inplace=True)
df
# Out:
#          State  Claim Amount Response  Coverage Education Effective To Date  \
# 0       Kansas    276.351928       No     Basic  Bachelor        2011-02-24
# 1     Nebraska    697.953590       No  Extended  Bachelor        2011-01-31
# 2     Oklahoma   1288.743165       No   Premium  Bachelor        2011-02-19
# 3     Missouri    764.586183       No     Basic  Bachelor        2011-01-20
# 4       Kansas    281.369258       No     Basic  Bachelor        2011-02-03
# ...        ...           ...      ...       ...       ...               ...
# 9129  Missouri   2340.598798       No     Basic  Bachelor        2011-02-10
# 9130  Missouri    309.651122      Yes  Extended   College        2011-02-12
# 9131  Missouri    816.389043       No  Extended  Bachelor        2011-02-06
# 9132  Missouri    752.444244       No  Extended   College        2011-02-03
# 9133  Missouri    261.183687       No  Extended   College        2011-02-14
#
# ...

# %%
# Converting the String or Object data to numeric types

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
# df['Region']=le.fit_transform(df['Region])

list1=['State','Response','Coverage','Education','EmploymentStatus','Gender','Location Code','Marital Status','Policy Type','Policy','Claim Reason','Sales Channel','Vehicle Class','Vehicle Size']

for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#       State  Claim Amount  Response  Coverage  Education Effective To Date  \
# 0         1    276.351928         0         0          0        2011-02-24
# 1         3    697.953590         0         1          0        2011-01-31
# 2         4   1288.743165         0         2          0        2011-02-19
# 3         2    764.586183         0         0          0        2011-01-20
# 4         1    281.369258         0         0          0        2011-02-03
# ...     ...           ...       ...       ...        ...               ...
# 9129      2   2340.598798         0         0          0        2011-02-10
# 9130      2    309.651122         1         1          1        2011-02-12
# 9131      2    816.389043         0         1          0        2011-02-06
# 9132      2    752.444244         0         1          1        2011-02-03
# 9133      2    261.183687         0         1          1        2011-02-14
#
#       EmploymentStatus  Gender  Income  Location Code  ...  \
# ...

# %%
df.dtypes
# Out:
# State                                     int32
# Claim Amount                            float64
# Response                                  int32
# Coverage                                  int32
# Education                                 int32
# Effective To Date                datetime64[ns]
# EmploymentStatus                          int32
# Gender                                    int32
# Income                                    int64
# Location Code                             int32
# Marital Status                            int32
# Monthly Premium Auto                      int64
# Months Since Last Claim                   int64
# Months Since Policy Inception             int64
# Number of Open Complaints                 int64
# Number of Policies                        int64
# Policy Type                               int32
# Policy                                    int32
# Claim Reason                              int32
# Sales Channel                             int32
# ...

# %%
# All string objects have been converted to integer types

# %%
# Summary of Statistics

df.describe()
# Out:
#              State  Claim Amount     Response     Coverage    Education  \
# count  9134.000000   9134.000000  9134.000000  9134.000000  9134.000000
# mean      1.722684    800.494047     0.143201     0.480622     1.554084
# std       1.312397    687.096761     0.350297     0.655817     1.381978
# min       0.000000    189.800768     0.000000     0.000000     0.000000
# 25%       0.000000    399.425179     0.000000     0.000000     0.000000
# 50%       2.000000    578.018220     0.000000     0.000000     1.000000
# 75%       3.000000    896.216704     0.000000     1.000000     3.000000
# max       4.000000   8332.538119     1.000000     2.000000     4.000000
#
#        EmploymentStatus       Gender        Income  Location Code  \
# count       9134.000000  9134.000000   9134.000000    9134.000000
# mean           1.825706     0.490037  37657.380009       0.979089
# std            1.347793     0.499928  30379.904734       0.605732
# ...

# %%
# Claim Amount is the attribute which is to be predicted

# since the target attribute (Claim Amount) is continuous we would be using regression for this prediction task........

# %% [markdown]
# # Data Visualisation

# %%
sns.heatmap(df.isnull())

# %%
# There are no null values otherwise we would have noticed the difference in shade colour

# %%
# Now let's check the null values without using visualisation
df.isnull().sum()
# Out:
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %% [markdown]
# # Checking out the Correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                                   State  Claim Amount  Response  Coverage  \
# State                          1.000000     -0.006629 -0.001732  0.007558
# Claim Amount                  -0.006629      1.000000 -0.008930  0.168040
# Response                      -0.001732     -0.008930  1.000000  0.000642
# Coverage                       0.007558      0.168040  0.000642  1.000000
# Education                      0.004256      0.026038  0.000285  0.021573
# EmploymentStatus              -0.004054     -0.034846 -0.016703  0.003239
# Gender                         0.000545     -0.013610  0.004396 -0.014448
# Income                         0.002682      0.024366  0.011932 -0.010646
# Location Code                  0.001382      0.004854  0.001729 -0.020176
# Marital Status                -0.008975     -0.026003 -0.094843  0.002956
# Monthly Premium Auto          -0.005549      0.396262  0.010966  0.458997
# Months Since Last Claim        0.009249      0.011517 -0.016597  0.016925
# ...

# %%
# Observations:

# Claim Amount has a weak positive correlation with Coverage, Education, Gender Income, Months Since Policy Inception

# Location Code and Sales Channel have very little impact on the claim amount.

# %%
sns.heatmap(dfcor)

# %%
plt.figure(figsize=(24,8))
sns.heatmap(dfcor,annot=True)

# %% [raw]
# Observations:
#
#     Lighter shades are highly correlated
#
#      Claim Amount is positively correlated with monthly premium auto, number of policies & total claim amount.
#
#      Location Code and Sales Channel have very little impact on the claim amount.
#
#      Claim Amount has a weak positive correlation with Coverage, Education, Gender,Income, Months Since Policy Inception

# %%
sns.pairplot(df)

# %% [markdown]
# # Bivariate Analysis

# %%
# Coverage vs Claim Amount

# 0-Basic
# 1-Extended
# 2-Premium

sns.barplot(x=df['Coverage'],y=df['Claim Amount'],data=df)
plt.show()

# Claim Amount is the highest for Extended Premium

# %%
# Marital Status vs Claim Amount

# 0-Divorced
# 1-Married
# 2-Single


sns.barplot(x=df['Marital Status'],y=df['Claim Amount'],data=df)
plt.show()

# Claim Amount is highest for divorced persons

# %%
# Response Vs Claim Amount

# 0-No
# 1-Yes

sns.barplot(x=df['Response'],y=df['Claim Amount'],data=df)
plt.show()

# %%
# Months Since Last Claim vs Claim Amount

sns.lineplot(x=df['Months Since Last Claim'],y=df['Claim Amount'],data=df)
plt.show()

# Claim amount is highest after 34-35 months of Past claim

# %%
# EmploymentStatus vs Claim Amount

sns.barplot(x=df['EmploymentStatus'],y=df['Claim Amount'],data=df)
plt.show()

# The maximum amount is claimed by 1 i.e. Employed People

# %%
# Total Claim Amount vs Claim Amount

sns.lineplot(x=df['Total Claim Amount'],y=df['Claim Amount'],data=df)
plt.show()

# In general the claim amount increases with the increase in Total Claim Amount

# %%
# Income vs Claim Amount

sns.lineplot(x=df['Income'],y=df['Claim Amount'],data=df)
plt.show()

# Maximum claim amount is observed at income levels of 60000

# %%
# Monthly Premium Auto vs Claim Amount

sns.lineplot(x=df['Monthly Premium Auto'],y=df['Claim Amount'],data=df)
plt.show()

# Maximum Claim amount is recorded between Premium Amounts of 200-240

# %%
# Number of Policies vs Claim Amount

sns.lineplot(x=df['Number of Policies'],y=df['Claim Amount'],data=df)
plt.show()

# Maximum claim amount is observed in cases of people with 2 policies. For more than 2 policies the claim amount is the same.

# %%
# Vehicle class vs Claim Amount

sns.lineplot(x=df['Vehicle Size'],y=df['Claim Amount'],data=df)
plt.show()

# In general as the vehicle size increases the Claim Amount also increases

# %%
# Observations

# Claim Amount is the highest for Extended Premium

# Claim Amount is highest for divorced persons

# Claim amount is highest after 34-35 months of Past claim

# The maximum amount is claimed by 1 i.e. Employed People

# Maximum claim amount is observed at income levels of 60000

# Maximum Claim amount is recorded between Premium Amounts of 200-240

# Maximum claim amount is observed in cases of people with 2 policies. For more than 2 policies the claim amount is the same.


# In general as the vehicle size increases the Claim Amount also increases

# %%
# Removing the Effective To Date column

df.drop('Effective To Date',axis=1,inplace=True)

# %% [markdown]
# # Plotting the Outliers

# %%
df.plot(kind='box',subplots=True, layout=(4,7))
# Out:
# State                                AxesSubplot(0.125,0.71587;0.0945122x0.16413)
# Claim Amount                      AxesSubplot(0.238415,0.71587;0.0945122x0.16413)
# Response                          AxesSubplot(0.351829,0.71587;0.0945122x0.16413)
# Coverage                          AxesSubplot(0.465244,0.71587;0.0945122x0.16413)
# Education                         AxesSubplot(0.578659,0.71587;0.0945122x0.16413)
# EmploymentStatus                  AxesSubplot(0.692073,0.71587;0.0945122x0.16413)
# Gender                            AxesSubplot(0.805488,0.71587;0.0945122x0.16413)
# Income                              AxesSubplot(0.125,0.518913;0.0945122x0.16413)
# Location Code                    AxesSubplot(0.238415,0.518913;0.0945122x0.16413)
# Marital Status                   AxesSubplot(0.351829,0.518913;0.0945122x0.16413)
# Monthly Premium Auto             AxesSubplot(0.465244,0.518913;0.0945122x0.16413)
# ...

# %% [markdown]
# # Checking the distribution of Skewness

# %%
collist=df.columns.values
ncol=12
nrows=10

# %%
plt.figure(figsize=(36,36))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
# Removing the outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.55068994, 0.76287773, 0.40882171, ..., 0.16963969, 1.49918077,
#         0.16668206],
#        [0.97332215, 0.14924546, 0.40882171, ..., 2.400737  , 0.91292371,
#         0.16668206],
#        [1.73532819, 0.71063622, 0.40882171, ..., 0.45573376, 1.49918077,
#         0.16668206],
#        ...,
#        [0.21131611, 0.02313483, 0.40882171, ..., 1.22793667, 0.91292371,
#         0.16668206],
#        [0.21131611, 0.06993547, 0.40882171, ..., 0.88511256, 0.91292371,
#         2.0278971 ],
#        [0.21131611, 0.78495478, 0.40882171, ..., 0.22200449, 1.49918077,
#         0.16668206]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  31,   50,   51,   79,   86,  125,  181,  185,  196,  196,  232,
#         243,  244,  248,  248,  266,  274,  281,  292,  303,  315,  316,
#         373,  375,  385,  386,  403,  404,  404,  407,  408,  418,  425,
#         435,  444,  496,  496,  510,  512,  522,  522,  541,  541,  554,
#         581,  581,  626,  633,  645,  680,  681,  702,  727,  749,  755,
#         757,  810,  814,  817,  820,  832,  832,  832,  836,  840,  856,
#         869,  873,  888,  888,  899,  914,  926,  944,  949, 1002, 1008,
#        1011, 1046, 1046, 1058, 1071, 1078, 1078, 1109, 1113, 1120, 1133,
#        1158, 1174, 1179, 1184, 1200, 1212, 1233, 1240, 1283, 1292, 1292,
#        1300, 1305, 1312, 1312, 1319, 1330, 1364, 1382, 1383, 1383, 1384,
#        1392, 1393, 1408, 1421, 1429, 1436, 1466, 1504, 1506, 1516, 1516,
#        1521, 1529, 1534, 1541, 1552, 1552, 1555, 1558, 1592, 1626, 1640,
#        1657, 1687, 1795, 1796, 1796, 1809, 1812, 1819, 1819, 1823, 1824,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       State  Claim Amount  Response  Coverage  Education  EmploymentStatus  \
# 0         1    276.351928         0         0          0                 1
# 1         3    697.953590         0         1          0                 4
# 2         4   1288.743165         0         2          0                 1
# 3         2    764.586183         0         0          0                 4
# 4         1    281.369258         0         0          0                 1
# ...     ...           ...       ...       ...        ...               ...
# 9129      2   2340.598798         0         0          0                 1
# 9130      2    309.651122         1         1          1                 1
# 9131      2    816.389043         0         1          0                 4
# 9132      2    752.444244         0         1          1                 1
# 9133      2    261.183687         0         1          1                 4
#
#       Gender  Income  Location Code  Marital Status  ...  \
# ...

# %%
df.shape
# Out:
# (9134, 22)

# %%
df_new.shape
# Out:
# (8470, 22)

# %%
# Lets check the skewness of the dataset
df_new.skew()
# Out:
# State                            0.019194
# Claim Amount                     1.848796
# Response                         2.030625
# Coverage                         1.080580
# Education                        0.337866
# EmploymentStatus                 0.844023
# Gender                           0.044411
# Income                           0.282827
# Location Code                    0.012291
# Marital Status                  -0.099961
# Monthly Premium Auto             1.330466
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        2.574570
# Number of Policies               1.226531
# Policy Type                     -0.459843
# Policy                          -0.415012
# Claim Reason                     0.725402
# Sales Channel                    0.503296
# Total Claim Amount               0.709643
# Vehicle Class                    0.403978
# Vehicle Size                     0.071461
# dtype: float64

# %%
# there is some skewness which needs to be treated

# %%
# Data Cleansing:

# Removing the missing values

# Dropping the negatively correlated columns

# Removing the outliers

# %%
# Removing the unncessary columns

# Sales Channel is not at all important. 

df_new.drop('Sales Channel',axis=1,inplace=True)

# %%
# Treating using log

for col in df_new.columns:
    if df_new.skew().loc[col]>0.55:
        df_new[col]=np.log1p(df_new[col])

# %%
# lets again check the skewness
df_new.skew()
# Out:
# State                            0.019194
# Claim Amount                     0.359738
# Response                         2.030625
# Coverage                         0.633709
# Education                        0.337866
# EmploymentStatus                 0.405261
# Gender                           0.044411
# Income                           0.282827
# Location Code                    0.012291
# Marital Status                  -0.099961
# Monthly Premium Auto             0.610522
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        1.831256
# Number of Policies               0.392925
# Policy Type                     -0.459843
# Policy                          -0.415012
# Claim Reason                     0.213051
# Total Claim Amount              -1.930304
# Vehicle Class                    0.403978
# Vehicle Size                     0.071461
# dtype: float64

# %%
# Separating the target and input values

df_x=df_new.drop(columns=['Claim Amount'])
y=df_new[['Claim Amount']]

# %%
# Scaling the input variable
# linear regression algorithm requires all features to be on a common scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
# Lets again check the skewness
x.skew()
# Out:
# State                            0.019194
# Response                         2.030625
# Coverage                         0.633709
# Education                        0.337866
# EmploymentStatus                 0.405261
# Gender                           0.044411
# Income                           0.282827
# Location Code                    0.012291
# Marital Status                  -0.099961
# Monthly Premium Auto             0.610522
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        1.831256
# Number of Policies               0.392925
# Policy Type                     -0.459843
# Policy                          -0.415012
# Claim Reason                     0.213051
# Total Claim Amount              -1.930304
# Vehicle Class                    0.403978
# Vehicle Size                     0.071461
# dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2 score corresponding to:',r_state,'is',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
            
    print('Maximum r2 score corresponding to:',final_r_state,'is:',max_r_score)
    return final_r_state

# %%
# Lets use Linear Regression and check max r2 score corresponding to different random states
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to: 42 is 0.34376910034815145
# r2 score corresponding to: 43 is 0.35522601013634636
# r2 score corresponding to: 44 is 0.30129723707559064
# r2 score corresponding to: 45 is 0.3529314733326706
# r2 score corresponding to: 46 is 0.32261372643264885
# r2 score corresponding to: 47 is 0.33203108442184526
# r2 score corresponding to: 48 is 0.34411184538422956
# r2 score corresponding to: 49 is 0.31903114847924285
# r2 score corresponding to: 50 is 0.3446536028253889
# r2 score corresponding to: 51 is 0.29907979198910795
# r2 score corresponding to: 52 is 0.3254625226840643
# r2 score corresponding to: 53 is 0.33113475426896066
# r2 score corresponding to: 54 is 0.325853824387374
# r2 score corresponding to: 55 is 0.3006721423262745
# r2 score corresponding to: 56 is 0.3306545140388688
# r2 score corresponding to: 57 is 0.30472879158207156
# r2 score corresponding to: 58 is 0.33215309347174804
# r2 score corresponding to: 59 is 0.35440256691609284
# ...

# %%
# Lets use grid_search to find the optimal value of n_neighbors for KNN  model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 11}

# %%
# Lets use KNN regression and check maximum r2 score corresponding to different random states
knr=KNeighborsRegressor(n_neighbors=11)
r_state=maxr2_score(knr,x,y)
# Out:
# r2 score corresponding to: 42 is 0.33323586225469004
# r2 score corresponding to: 43 is 0.35654484787659546
# r2 score corresponding to: 44 is 0.3639852920217743
# r2 score corresponding to: 45 is 0.3843690718386318
# r2 score corresponding to: 46 is 0.3251939592992892
# r2 score corresponding to: 47 is 0.3613371167168463
# r2 score corresponding to: 48 is 0.3774414936685718
# r2 score corresponding to: 49 is 0.3705634996688725
# r2 score corresponding to: 50 is 0.35875734889140287
# r2 score corresponding to: 51 is 0.34089523091990925
# r2 score corresponding to: 52 is 0.36397703228375355
# r2 score corresponding to: 53 is 0.36190013267243604
# r2 score corresponding to: 54 is 0.3684074943028468
# r2 score corresponding to: 55 is 0.3505164130888797
# r2 score corresponding to: 56 is 0.3517014524106057
# r2 score corresponding to: 57 is 0.32758573747220654
# r2 score corresponding to: 58 is 0.3598371459784061
# r2 score corresponding to: 59 is 0.38312031583631867
# ...

# %%
# Lets check the mean r2 score of both linear regression model and knn regression
from sklearn.model_selection import cross_val_score
print('Mean r2 score for linear regression: ', cross_val_score(lreg,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for Linear Regression:',cross_val_score(lreg,x,y,cv=5,scoring='r2').std())
print()
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for linear regression:  0.3273374997800419
# Standard deviation in r2 score for Linear Regression: 0.013332064113372238
#
# Mean r2 score for KNN Regression: 0.35961776824463626
# Standard deviation in r2 score for KNN Regression: 0.010613065678428426

# %%
# Lets check Lasso Regression and the best value of alpha
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={'alpha':[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
# Lets check the maximum r2 score when we use Lasso
lsreg=Lasso(alpha=0.1)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to: 42 is 0.27935314400659894
# r2 score corresponding to: 43 is 0.27900429798036763
# r2 score corresponding to: 44 is 0.2500231851867635
# r2 score corresponding to: 45 is 0.28211520432846615
# r2 score corresponding to: 46 is 0.2668849838633778
# r2 score corresponding to: 47 is 0.2729616225170134
# r2 score corresponding to: 48 is 0.27751628742807644
# r2 score corresponding to: 49 is 0.2688183166379602
# r2 score corresponding to: 50 is 0.27230198948430695
# r2 score corresponding to: 51 is 0.2505996816970225
# r2 score corresponding to: 52 is 0.270277037706823
# r2 score corresponding to: 53 is 0.2679911496811941
# r2 score corresponding to: 54 is 0.2685071444088003
# r2 score corresponding to: 55 is 0.25038609344431384
# r2 score corresponding to: 56 is 0.2649436536430416
# r2 score corresponding to: 57 is 0.2527531082543343
# r2 score corresponding to: 58 is 0.2770889659509891
# r2 score corresponding to: 59 is 0.2786907706380004
# ...

# %%
# Lets use the cross val score with Lasso

print('Mean r2 score for Lasso regression: ', cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for Lasso Regression:',cross_val_score(lreg,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for Lasso regression:  0.26669134705475983
# Standard deviation in r2 score for Lasso Regression: 0.013332064113372238

# %%
# Now we will try to use the gradient boosting technique

# For getting the best set of parameters we will use grid search

from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings('ignore')
gbr=GradientBoostingRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=500)
r_state=maxr2_score(gbr,x,y)
# Out:
# r2 score corresponding to: 42 is 0.9192300560413034
# r2 score corresponding to: 43 is 0.9212961570392757
# r2 score corresponding to: 44 is 0.9134999825002457
# r2 score corresponding to: 45 is 0.9222570956426814
# r2 score corresponding to: 46 is 0.9135666275645444
# r2 score corresponding to: 47 is 0.9186305720565433
# r2 score corresponding to: 48 is 0.9176055741507685
# r2 score corresponding to: 49 is 0.921938646230276
# r2 score corresponding to: 50 is 0.9156649799858895
# r2 score corresponding to: 51 is 0.9054133628943666
# r2 score corresponding to: 52 is 0.9185599048596721
# r2 score corresponding to: 53 is 0.915976341805395
# r2 score corresponding to: 54 is 0.91508561760023
# r2 score corresponding to: 55 is 0.9131759630663572
# r2 score corresponding to: 56 is 0.919124970268967
# r2 score corresponding to: 57 is 0.9131235192859648
# r2 score corresponding to: 58 is 0.9193114364001769
# r2 score corresponding to: 59 is 0.9260171105694164
# ...

# %%
# Now we will use the cross_val_score to check the mean r2 score and standard deviation

print('Mean r2 score for Gradient boosting regression: ', cross_val_score(gbr,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for Gradient boosting regression:',cross_val_score(gbr,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for Gradient boosting regression:  0.9172417379080002
# Standard deviation in r2 score for Gradient boosting regression: 0.003947257422756326

# %%
feat_importances = pd.Series(gbr.feature_importances_, index=x.columns)
feat_importances = feat_importances.nlargest(20)
feat_importances.plot(kind='barh')

# %%
#  Top 10 factors or attributes which contribute the most towards Claim Amount in descending order are: 

# 1) Number of Policies 
# 2) Monthly Premium Auto
# 3) Income 
# 4) Total Claim Amount
# 5) Months Since Policy Inception
# 6) Employment Status
# 7) Months Since Last Claim
# 8) Response
# 9) Marital Satus
# 10) Coverage

# %%
# Now lets use adaboost regression algorithm

# Adaboost Regression Algorithm doesn't respond with the best parameters due to the large dataset. System gets hanged

# from sklearn.ensemble import AdaBoostRegressor
# from sklearn.tree import DecisionTreeRegressor
# ada_reg=AdaBoostRegressor()
# parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000],'base_estimator':[lreg,lsreg,DecisionTreeRegressor()]}
# clf=GridSearchCV(ada_reg,parameters,cv=5)
# clf.fit(x,y)
# clf.best_params

# %%
# We tried all the models and found that Gradient boosting regressor is the best
# Random state corresponding to highest r2 score is 73

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=73,test_size=0.20)
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
y_pred=gbr.predict(x_test)

# %%
# Lets find the rmse and r2 score using sklearn.metrics

import numpy as np

print('RMSE is:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2 score is:',r2_score(y_test,y_pred))
# Out:
# RMSE is: 0.15919562290775482
# r2 score is: 0.925590562529469

# %%
from sklearn.externals import joblib

# Save the model as a pickle in a file

joblib.dump(gbr,'ClaimAmount.obj')
# Out:
# ['ClaimAmount.obj']

# %%
# load the model from the file

gbr_from_joblib=joblib.load('ClaimAmount.obj')

# Use the loaded model to make predictions

gbr_from_joblib.predict(x_test)
# Out:
# array([6.56394239, 6.61437699, 6.53474277, ..., 6.17436131, 6.98950409,
#        6.13203895])

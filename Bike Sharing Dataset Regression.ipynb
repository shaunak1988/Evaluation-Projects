# %%
import pandas as pd
df_bikes_hour=pd.read_csv('hour.csv')
df_bikes_hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
df_bikes_hour=pd.read_csv('hour.csv',parse_dates=['dteday'])
df_bikes_hour
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
df_bikes_day=pd.read_csv('day.csv',parse_dates=['dteday'])
df_bikes_day
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 2          3 2011-01-03       1   0     1        0        1           1
# 3          4 2011-01-04       1   0     1        0        2           1
# 4          5 2011-01-05       1   0     1        0        3           1
# ..       ...        ...     ...  ..   ...      ...      ...         ...
# 726      727 2012-12-27       1   1    12        0        4           1
# 727      728 2012-12-28       1   1    12        0        5           1
# 728      729 2012-12-29       1   1    12        0        6           0
# 729      730 2012-12-30       1   1    12        0        0           0
# 730      731 2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
# Both hour.csv and day.csv have the same fields except hour which is not available in day.csv

# %%
# Casual and registered are superfluous columns and its better to drop them.

df_bikes_hour.drop(['casual','registered'],axis=1,inplace=True)

# %%
df_bikes_hour
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
df_bikes_hour.shape
# Out:
# (17379, 15)

# %%
# Checking the datatypes
df_bikes_hour.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# cnt                    int64
# dtype: object

# %%
df_bikes_hour.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt'],
#       dtype='object')

# %%
df_bikes_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 15 columns):
# instant       17379 non-null int64
# dteday        17379 non-null datetime64[ns]
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# cnt           17379 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(10)
# memory usage: 2.0 MB

# %%
# Summary of Statistics

df_bikes_hour.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
Key Observations:
    
    # From dteday column we can get monthly,daily,yearly average counts of bikes which can help in data analysis
    
    # The values of the target/dependent variable are continuous and hence linear regression is the most suited

# %%
# Check whether there are null values or not
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_bikes_hour.isnull())
plt.show()

# %%
# There are no null values

# %%
# From dteday we can get monthly,daily,yearly average counts of bikes which can help in data analysis

df_bikes_dates=pd.DataFrame()
df_bikes_dates['month']=df_bikes_hour['dteday'].dt.month_name()
df_bikes_dates['year']=df_bikes_hour['dteday'].dt.year
df_bikes_dates['day']=df_bikes_hour['dteday'].dt.day_name()
df_bikes_dates['count']=df_bikes_hour['cnt']
df_bikes_dates
# Out:
#           month  year       day  count
# 0       January  2011  Saturday     16
# 1       January  2011  Saturday     40
# 2       January  2011  Saturday     32
# 3       January  2011  Saturday     13
# 4       January  2011  Saturday      1
# ...         ...   ...       ...    ...
# 17374  December  2012    Monday    119
# 17375  December  2012    Monday     89
# 17376  December  2012    Monday     90
# 17377  December  2012    Monday     61
# 17378  December  2012    Monday     49
#
# [17379 rows x 4 columns]

# %%
# Checking the total number of distinct years

df_bikes_dates['year'].drop_duplicates()
# Out:
# 0       2011
# 8645    2012
# Name: year, dtype: int64

# %%
# making one more column (type of the day) which tells whether it is weekday or weekend

import numpy as np
df_bikes_dates['type_of_the_day']=np.where((df_bikes_dates['day']=='Saturday')|(df_bikes_dates['day']=='Sunday'),'Weekend','Weekday')
df_bikes_dates
# Out:
#           month  year       day  count type_of_the_day
# 0       January  2011  Saturday     16         Weekend
# 1       January  2011  Saturday     40         Weekend
# 2       January  2011  Saturday     32         Weekend
# 3       January  2011  Saturday     13         Weekend
# 4       January  2011  Saturday      1         Weekend
# ...         ...   ...       ...    ...             ...
# 17374  December  2012    Monday    119         Weekday
# 17375  December  2012    Monday     89         Weekday
# 17376  December  2012    Monday     90         Weekday
# 17377  December  2012    Monday     61         Weekday
# 17378  December  2012    Monday     49         Weekday
#
# [17379 rows x 5 columns]

# %%
# Lets make a barplot for the average count during weekend and weekdays

sns.barplot(x='type_of_the_day',y='count',data=df_bikes_dates)
plt.show()

# %%
# Average counts during days of the week

sns.barplot(x='day',y='count',data=df_bikes_dates)
plt.show()

# %%
# Average counts during month of the year

sns.barplot(x='month',y='count',data=df_bikes_dates)
plt.show()

# %% [raw]
# # It shows that the bike rental count is more in summers (April,May,June,July,August,September,October) and shows a declining trend in winters (November-January) and again starts increasing in February and March

# %%
# Now lets compare the various quantitative features/input variables with the rental counts

# %%
# Using lineplot from seaborn to check how the count varies with temperature

sns.lineplot(x='temp',y='cnt',data=df_bikes_hour)
plt.show()

# %%
# Using lineplot from seaborn to check how the count varies with normalized feeling temperature(atemp)

sns.lineplot(x='atemp',y='cnt',data=df_bikes_hour)
plt.show()

# %%
# Change with humidity

sns.lineplot(x='hum',y='cnt',data=df_bikes_hour)
plt.show()

# %%
# Change with windspeed

sns.lineplot(x='windspeed',y='cnt',data=df_bikes_hour)
plt.show()

# %%
# Counts of bike rentals by season

sns.barplot(x='season',y='cnt',data=df_bikes_hour)
plt.show()

# %% [raw]
# If 1 is spring, 2 is summer, 3 is fall and 4 is winter then people tend to rent bikes more in the 'fall' season

# %%
# Counts of bike rentals by weathersit(weather conditions)

sns.barplot(x='weathersit',y='cnt',data=df_bikes_hour)
plt.show()

# %% [raw]
# # If 1 is clear weather , 2 is mist, 3 is Light snow and 4 is heavy rain than people tend to rent bikes more in clear weather.

# %%
# Total bike rentals by hour

sns.barplot(x='hr',y='cnt',data=df_bikes_hour)
plt.show()

# %% [raw]
# Peak office hours and evenings see the maximum number of bike rentals

# %%
# Lets check the skewness of the dataset
df_bikes_hour.skew()
# Out:
# instant       0.000000
# season       -0.005416
# yr           -0.010243
# mnth         -0.009253
# hr           -0.010680
# holiday       5.638538
# weekday      -0.002998
# workingday   -0.785258
# weathersit    1.228047
# temp         -0.006021
# atemp        -0.090429
# hum          -0.111287
# windspeed     0.574905
# cnt           1.277412
# dtype: float64

# %%
# Separating the input and output variables

df_x=df_bikes_hour.drop(columns=['cnt','dteday'])
x
# Out:
#        instant  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1       1   0     1   0        0        6           0
# 1            2       1   0     1   1        0        6           0
# 2            3       1   0     1   2        0        6           0
# 3            4       1   0     1   3        0        6           0
# 4            5       1   0     1   4        0        6           0
# ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375       1   1    12  19        0        1           1
# 17375    17376       1   1    12  20        0        1           1
# 17376    17377       1   1    12  21        0        1           1
# 17377    17378       1   1    12  22        0        1           1
# 17378    17379       1   1    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed
# 0               1  0.24  0.2879  0.81     0.0000
# 1               1  0.22  0.2727  0.80     0.0000
# ...

# %%
y=df_bikes_hour[['cnt']]
y
# Out:
#        cnt
# 0       16
# 1       40
# 2       32
# 3       13
# 4        1
# ...    ...
# 17374  119
# 17375   89
# 17376   90
# 17377   61
# 17378   49
#
# [17379 rows x 1 columns]

# %%
# Scaling the input variable
# linear regression algorithm requires all features to be on a common scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
# Lets again check the skewness
x.skew()
# Out:
# instant      -1.947323e-17
# season       -5.415699e-03
# yr           -1.024326e-02
# mnth         -9.253248e-03
# hr           -1.067991e-02
# holiday       5.638538e+00
# weekday      -2.998221e-03
# workingday   -7.852580e-01
# weathersit    1.228047e+00
# temp         -6.020883e-03
# atemp        -9.042886e-02
# hum          -1.112871e-01
# windspeed     5.749052e-01
# dtype: float64

# %%
# there is some skewness which needs to be treated

# %%
# Treating using log

for col in x.columns:
    if x.skew().loc[col]>0.55:
        x[col]=np.log1p(x[col])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
x.skew()
# Out:
# instant      -1.947323e-17
# season       -5.415699e-03
# yr           -1.024326e-02
# mnth         -9.253248e-03
# hr           -1.067991e-02
# holiday       5.638538e+00
# weekday      -2.998221e-03
# workingday   -7.852580e-01
# weathersit    7.555903e-01
# temp         -6.020883e-03
# atemp        -9.042886e-02
# hum          -1.112871e-01
# windspeed    -4.970992e-01
# dtype: float64

# %%
# Skewness has been somewhat reduced in the windspeed column

# %%
x.shape
# Out:
# (17379, 13)

# %%
y.shape
# Out:
# (17379, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
# Here we will find out the random state value which our linear model learns maximum

from sklearn.metrics import r2_score
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print('Maximum r2 score corresponding to:',final_r_state,'is:',max_r_score)
# Out:
# Maximum r2 score corresponding to: 72 is: 0.40999169997341056

# %%
from sklearn.model_selection import cross_val_score

# %%
# Lets use cross_val_score to check whether it is overfitting or not

a_score=cross_val_score(linear_model.LinearRegression(),df_x,y,cv=5,scoring='r2')
a_score

# By cross validation we came to know that our model is performing satisfactory and if we want to further improve its performance then we need more data
# Out:
# array([0.14391333, 0.26703282, 0.19373011, 0.29566086, 0.30906085])

# %%
# Lets make our final model

x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=72,test_size=0.20)
regr=linear_model.LinearRegression()
regr.fit(x_train,y_train)
y_pred=regr.predict(x_test)

# %%
print('r2 score is:',r2_score(y_test,y_pred))
print('RMSE is:',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is: 0.40999169997341056
# RMSE is: 141.5851348352334

# %%
from sklearn.externals import joblib

# Save the model as a pickle in a file

joblib.dump(regr,'bikes_sharing_dataset_regression.obj')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['bikes_sharing_dataset_regression.obj']

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
column_names=['CIC0','SM1_Dz(Z)','GATS1i','NDsCH','NDssC','MLOGP','QR_LC50']
df=pd.read_csv('qsar_fish_toxicity.csv',delimiter=";",names=column_names)
df
# Out:
#       CIC0  SM1_Dz(Z)  GATS1i  NDsCH  NDssC  MLOGP  QR_LC50
# 0    3.260      0.829   1.676      0      1  1.453    3.770
# 1    2.189      0.580   0.863      0      0  1.348    3.115
# 2    2.125      0.638   0.831      0      0  1.348    3.531
# 3    3.027      0.331   1.472      1      0  1.807    3.510
# 4    2.094      0.827   0.860      0      0  1.886    5.390
# ..     ...        ...     ...    ...    ...    ...      ...
# 903  2.801      0.728   2.226      0      2  0.736    3.109
# 904  3.652      0.872   0.867      2      3  3.983    4.040
# 905  3.763      0.916   0.878      0      6  2.918    4.818
# 906  2.831      1.393   1.077      0      1  0.906    5.317
# 907  4.057      1.032   1.183      1      3  4.754    8.201
#
# [908 rows x 7 columns]

# %% [raw]
# # Quantitative Response LC50 is the attribute which needs to be predicted
#
# # since the target attribute (Quantitative Response LC50) is continuous we would be using regression for the prediction task........

# %%
df.head()
# Out:
#     CIC0  SM1_Dz(Z)  GATS1i  NDsCH  NDssC  MLOGP  QR_LC50
# 0  3.260      0.829   1.676      0      1  1.453    3.770
# 1  2.189      0.580   0.863      0      0  1.348    3.115
# 2  2.125      0.638   0.831      0      0  1.348    3.531
# 3  3.027      0.331   1.472      1      0  1.807    3.510
# 4  2.094      0.827   0.860      0      0  1.886    5.390

# %%
df.shape
# Out:
# (908, 7)

# %%
df.dtypes
# Out:
# CIC0         float64
# SM1_Dz(Z)    float64
# GATS1i       float64
# NDsCH          int64
# NDssC          int64
# MLOGP        float64
# QR_LC50      float64
# dtype: object

# %%
df.columns
# Out:
# Index(['CIC0', 'SM1_Dz(Z)', 'GATS1i', 'NDsCH', 'NDssC', 'MLOGP', 'QR_LC50'], dtype='object')

# %%
# Summary of Statistics

df.describe()
# Out:
#              CIC0   SM1_Dz(Z)      GATS1i       NDsCH       NDssC       MLOGP  \
# count  908.000000  908.000000  908.000000  908.000000  908.000000  908.000000
# mean     2.898129    0.628468    1.293591    0.229075    0.485683    2.109285
# std      0.756088    0.428459    0.394303    0.605335    0.861279    1.433181
# min      0.667000    0.000000    0.396000    0.000000    0.000000   -2.884000
# 25%      2.347000    0.223000    0.950750    0.000000    0.000000    1.209000
# 50%      2.934000    0.570000    1.240500    0.000000    0.000000    2.127000
# 75%      3.407000    0.892750    1.562250    0.000000    1.000000    3.105000
# max      5.926000    2.171000    2.920000    4.000000    6.000000    6.515000
#
#           QR_LC50
# count  908.000000
# mean     4.064431
# std      1.455698
# min      0.053000
# 25%      3.151750
# 50%      3.987500
# 75%      4.907500
# max      9.612000

# %%
df.QR_LC50.value_counts()
# Out:
# 4.208    4
# 3.513    4
# 3.660    3
# 3.470    3
# 3.926    3
#         ..
# 1.301    1
# 4.513    1
# 3.507    1
# 4.544    1
# 3.250    1
# Name: QR_LC50, Length: 827, dtype: int64

# %% [raw]
# Key Observations:
#
#     Target/Dependent variable has continuous values

# %% [markdown]
# # Data Visualisation

# %%
sns.heatmap(df.isnull())

# %%
# Now let's check the null values without using visualisation
df.isnull().sum()
# Out:
# CIC0         0
# SM1_Dz(Z)    0
# GATS1i       0
# NDsCH        0
# NDssC        0
# MLOGP        0
# QR_LC50      0
# dtype: int64

# %%
# There are no null values

# %% [markdown]
# # Checking out the correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                CIC0  SM1_Dz(Z)    GATS1i     NDsCH     NDssC     MLOGP  \
# CIC0       1.000000  -0.235360  0.147622  0.121341  0.246639  0.463867
# SM1_Dz(Z) -0.235360   1.000000 -0.145967 -0.141401  0.163179  0.200663
# GATS1i     0.147622  -0.145967  1.000000 -0.010657  0.092410 -0.450739
# NDsCH      0.121341  -0.141401 -0.010657  1.000000  0.188164  0.048620
# NDssC      0.246639   0.163179  0.092410  0.188164  1.000000  0.028499
# MLOGP      0.463867   0.200663 -0.450739  0.048620  0.028499  1.000000
# QR_LC50    0.291854   0.410893 -0.397965  0.172004  0.172390  0.651664
#
#             QR_LC50
# CIC0       0.291854
# SM1_Dz(Z)  0.410893
# GATS1i    -0.397965
# NDsCH      0.172004
# NDssC      0.172390
# MLOGP      0.651664
# QR_LC50    1.000000

# %% [raw]
# Observations:
#
# LC50(Aquatic toxicty) levels are strongly correlated with MLOGP and SM1_Dz(Z) levels
#
# GATs1i has a negative correlation with LC50 levels
#
# CIC0,NDsCH,NDssC have a weak correlation with LC50(Aquatic toxicity) levels

# %%
sns.heatmap(dfcor)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,annot=True)

# %% [raw]
# Observations:
#
#
#     Lighter shades are highly correlated whereas the lighter ones are not
#
#     LC50(Aquatic toxicty) levels are strongly correlated with MLOGP and SM1_Dz(Z) levels
#
#     GATs1i has a negative correlation with LC50 levels
#
#     CIC0,NDsCH,NDssC have a weak correlation with LC50(Aquatic toxicity) levels

# %% [markdown]
# # Plotting the outliers

# %%
df.plot(kind='box',subplots=True, layout=(2,7))
# Out:
# CIC0            AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# SM1_Dz(Z)    AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# GATS1i       AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# NDsCH        AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# NDssC        AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# MLOGP        AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# QR_LC50      AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# dtype: object

# %%
sns.pairplot(df)

# %% [markdown]
# # Bivariate Analysis

# %%
# CIC0 vs QR_LC50

sns.lineplot(x=df['CIC0'],y=df['QR_LC50'],data=df)
plt.show()

# Maximum LC50 levels are observed between 4 and 5 levels of CIC0

# %%
# SM1_Dz(Z) vs QR_LC50 

sns.lineplot(x=df['SM1_Dz(Z)'],y=df['QR_LC50'],data=df)
plt.show()

# Maximum LC50 levels are observed at 1.25 level of SM1_Dz(Z)

# %%
# GATS1i vs QR_LC50

sns.lineplot(x=df['GATS1i'],y=df['QR_LC50'],data=df)
plt.show()

# GATS1i seems to have a negative correlation with LC50 (toxicity levels ) i.e. increased levels of GATS1i lead to reduced levels of LC50

# %%
# NDsCH vs QR_LC50 

sns.lineplot(x=df['NDsCH'],y=df['QR_LC50'],data=df)
plt.show()

# Increased NDsCH levels lead to increased toxicity(LC50) levels

# %%
# NDssC vs QR_LC50 

sns.lineplot(x=df['NDssC'],y=df['QR_LC50'],data=df)
plt.show()


# In general increased NDssC levels lead to increased toxicity(LC50) levels upto 5 

# But after 5 when the value of NDssC increases there is a slight decline in the toxicity levels (LC50)

# %%
# MLOGP vs QR_LC50 

sns.lineplot(x=df['MLOGP'],y=df['QR_LC50'],data=df)
plt.show()


# In general increased MLOGP levels lead to increased toxicity(LC50) levels

# %% [raw]
# # Observations
#
#
# # In general increased MLOGP levels lead to increased toxicity(LC50) levels
#
# # In general increased NDssC levels lead to increased toxicity(LC50) levels upto 5
#
# # But after 5 when the value of NDssC increases there is a slight decline in the toxicity levels (LC50)
#
# # Increased NDsCH levels lead to increased toxicity(LC50) levels
#
# # GATS1i seems to have a negative correlation with LC50 (toxicity levels ) i.e. increased levels of GATS1i lead to reduced levels of LC50
#
# # Maximum LC50 levels are observed at 1.25 level of SM1_Dz(Z)
#
# # Maximum LC50 levels are observed between 4 and 5 levels of CIC0

# %% [markdown]
# # To check the distribution of skewness

# %%
collist=df.columns.values
ncol=12
nrows=10

# %%
plt.figure(figsize=(36,36))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %% [markdown]
# # Plotting the Histograms

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018790050148>,
# ...
#       dtype=object)

# %%
# Removing the outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.47887329, 0.46828848, 0.97036948, ..., 0.59748428, 0.45817453,
#         0.20237219],
#        [0.93840825, 0.11318414, 1.09263435, ..., 0.56421963, 0.53147852,
#         0.652576  ],
#        [1.02310108, 0.02225928, 1.173835  , ..., 0.56421963, 0.53147852,
#         0.36664503],
#        ...,
#        [1.14450599, 0.67145361, 1.05457155, ..., 6.40600388, 0.56459064,
#         0.5179539 ],
#        [0.08883332, 1.78535897, 0.54960505, ..., 0.59748428, 0.8400534 ,
#         0.86093359],
#        [1.53356366, 0.94234045, 0.28062792, ..., 2.92089212, 1.84636323,
#         2.84320501]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 18,  38,  61,  84, 122, 177, 259, 259, 264, 277, 320, 339, 339,
#        363, 372, 372, 461, 462, 479, 499, 549, 577, 582, 618, 661, 663,
#        680, 696, 708, 708, 723, 725, 758, 760, 779, 782, 825, 889, 891,
#        892, 899, 900, 905], dtype=int64), array([2, 3, 3, 0, 2, 6, 4, 6, 3, 1, 4, 3, 4, 6, 1, 5, 1, 3, 4, 2, 3, 3,
#        4, 3, 2, 6, 6, 3, 2, 5, 4, 3, 3, 2, 2, 4, 3, 6, 4, 6, 4, 4, 4],
#       dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       CIC0  SM1_Dz(Z)  GATS1i  NDsCH  NDssC  MLOGP  QR_LC50
# 0    3.260      0.829   1.676      0      1  1.453    3.770
# 1    2.189      0.580   0.863      0      0  1.348    3.115
# 2    2.125      0.638   0.831      0      0  1.348    3.531
# 3    3.027      0.331   1.472      1      0  1.807    3.510
# 4    2.094      0.827   0.860      0      0  1.886    5.390
# ..     ...        ...     ...    ...    ...    ...      ...
# 902  3.475      0.405   0.875      1      2  3.148    4.803
# 903  2.801      0.728   2.226      0      2  0.736    3.109
# 904  3.652      0.872   0.867      2      3  3.983    4.040
# 906  2.831      1.393   1.077      0      1  0.906    5.317
# 907  4.057      1.032   1.183      1      3  4.754    8.201
#
# [869 rows x 7 columns]

# %%
df.shape
# Out:
# (908, 7)

# %%
df_new.shape
# Out:
# (869, 7)

# %%
# Lets check the skewness of the dataset
df_new.skew()
# Out:
# CIC0        -0.056835
# SM1_Dz(Z)    0.615042
# GATS1i       0.533461
# NDsCH        2.572829
# NDssC        1.675266
# MLOGP       -0.019217
# QR_LC50      0.065133
# dtype: float64

# %%
# there is some skewness which needs to be treated

# %%
# Treating using log

for col in df_new.columns:
    if df_new.skew().loc[col]>0.55:
        df_new[col]=np.log1p(df_new[col])

# %%
# lets again check the skewness
df_new.skew()
# Out:
# CIC0        -0.056835
# SM1_Dz(Z)    0.192861
# GATS1i       0.533461
# NDsCH        2.216376
# NDssC        1.203885
# MLOGP       -0.019217
# QR_LC50      0.065133
# dtype: float64

# %%
# Skewness has been reduced

# %%
# Separating the target and input values

df_x=df_new.drop(columns=['QR_LC50'])
y=df_new[['QR_LC50']]

# %%
# Scaling the input variable
# linear regression algorithm requires all features to be on a common scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
# Lets again check the skewness
x.skew()
# Out:
# CIC0        -0.056835
# SM1_Dz(Z)    0.192861
# GATS1i       0.533461
# NDsCH        2.216376
# NDssC        1.203885
# MLOGP       -0.019217
# dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2 score corresponding to:',r_state,'is',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
            
    print('Maximum r2 score corresponding to:',final_r_state,'is:',max_r_score)
    return final_r_state

# %%
# Lets use Linear Regression and check max r2 score corresponding to different random states
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to: 42 is 0.44474749247081213
# r2 score corresponding to: 43 is 0.542330236641783
# r2 score corresponding to: 44 is 0.50183865955702
# r2 score corresponding to: 45 is 0.4363223396814504
# r2 score corresponding to: 46 is 0.5673484499897552
# r2 score corresponding to: 47 is 0.5357624488863426
# r2 score corresponding to: 48 is 0.6543584642614457
# r2 score corresponding to: 49 is 0.5548832761768602
# r2 score corresponding to: 50 is 0.5803552218387138
# r2 score corresponding to: 51 is 0.5793502931043464
# r2 score corresponding to: 52 is 0.5279550863559656
# r2 score corresponding to: 53 is 0.5987551699810848
# r2 score corresponding to: 54 is 0.6118857649738896
# r2 score corresponding to: 55 is 0.5149214507412253
# r2 score corresponding to: 56 is 0.6011727594076945
# r2 score corresponding to: 57 is 0.6172486551741698
# r2 score corresponding to: 58 is 0.46090313292101537
# r2 score corresponding to: 59 is 0.4727496797397217
# ...

# %%
# Lets use grid_search to find the optimal value of n_neighbors for KNN  model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'n_neighbors': 11}

# %%
# Lets use KNN regression and check maximum r2 score corresponding to different random states
knr=KNeighborsRegressor(n_neighbors=11)
r_state=maxr2_score(knr,x,y)
# Out:
# r2 score corresponding to: 42 is 0.5328072706581233
# r2 score corresponding to: 43 is 0.5627228857086095
# r2 score corresponding to: 44 is 0.6099740606861326
# r2 score corresponding to: 45 is 0.572070293566916
# r2 score corresponding to: 46 is 0.6270479094256953
# r2 score corresponding to: 47 is 0.6048882272126278
# r2 score corresponding to: 48 is 0.6939558643899542
# r2 score corresponding to: 49 is 0.6247865939017387
# r2 score corresponding to: 50 is 0.6081963932675885
# r2 score corresponding to: 51 is 0.6337037116966282
# r2 score corresponding to: 52 is 0.5843195081059249
# r2 score corresponding to: 53 is 0.619592380886121
# r2 score corresponding to: 54 is 0.6823369700049591
# r2 score corresponding to: 55 is 0.6112743418085008
# r2 score corresponding to: 56 is 0.640514866647482
# r2 score corresponding to: 57 is 0.6210440920881145
# r2 score corresponding to: 58 is 0.5420464294191658
# r2 score corresponding to: 59 is 0.495566848815408
# ...

# %%
# Lets check the mean r2 score of both linear regression model and knn regression
from sklearn.model_selection import cross_val_score
print('Mean r2 score for linear regression: ', cross_val_score(lreg,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for Linear Regression:',cross_val_score(lreg,x,y,cv=5,scoring='r2').std())
print()
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for linear regression:  0.5264095252680338
# Standard deviation in r2 score for Linear Regression: 0.09908360615255252
#
# Mean r2 score for KNN Regression: 0.5687591306308928
# Standard deviation in r2 score for KNN Regression: 0.09526639137455821

# %%
# Lets check Lasso Regression and the best value of alpha
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={'alpha':[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'alpha': 0.01}

# %%
# Lets check the maximum r2 score when we use Lasso
lsreg=Lasso(alpha=0.01)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to: 42 is 0.44693216450004203
# r2 score corresponding to: 43 is 0.544513892478529
# r2 score corresponding to: 44 is 0.5046768497734466
# r2 score corresponding to: 45 is 0.4378341764164967
# r2 score corresponding to: 46 is 0.5694392051576598
# r2 score corresponding to: 47 is 0.5383168888641259
# r2 score corresponding to: 48 is 0.6558177646317345
# r2 score corresponding to: 49 is 0.5560265608495647
# r2 score corresponding to: 50 is 0.578106075532927
# r2 score corresponding to: 51 is 0.5788802335271357
# r2 score corresponding to: 52 is 0.5277235675208323
# r2 score corresponding to: 53 is 0.5985392111077199
# r2 score corresponding to: 54 is 0.6128650210316449
# r2 score corresponding to: 55 is 0.516150094640873
# r2 score corresponding to: 56 is 0.6008886114075906
# r2 score corresponding to: 57 is 0.6184193782406688
# r2 score corresponding to: 58 is 0.46662209373473396
# r2 score corresponding to: 59 is 0.47484376929981764
# ...

# %%
# Lets use the cross val score with Lasso

print('Mean r2 score for Lasso regression: ', cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for Lasso Regression:',cross_val_score(lreg,x,y,cv=5,scoring='r2').std())

# Based on the below output one can say that Lasso performed just like Linear Regression
# Out:
# Mean r2 score for Lasso regression:  0.5266859094375343
# Standard deviation in r2 score for Lasso Regression: 0.09908360615255252

# %%
# Now we will try to use the gradient boosting technique

# For getting the best set of parameters we will use grid search

from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings('ignore')
gbr=GradientBoostingRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 500}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=500)
r_state=maxr2_score(gbr,x,y)
# Out:
# r2 score corresponding to: 42 is 0.5261834450949385
# r2 score corresponding to: 43 is 0.6140364866992118
# r2 score corresponding to: 44 is 0.6024169624042723
# r2 score corresponding to: 45 is 0.5271014903538407
# r2 score corresponding to: 46 is 0.6055106614818468
# r2 score corresponding to: 47 is 0.5897736194275409
# r2 score corresponding to: 48 is 0.6413017203712921
# r2 score corresponding to: 49 is 0.5552373715818969
# r2 score corresponding to: 50 is 0.6375632646258832
# r2 score corresponding to: 51 is 0.5983825600589324
# r2 score corresponding to: 52 is 0.5467684285383753
# r2 score corresponding to: 53 is 0.6206248254818506
# r2 score corresponding to: 54 is 0.6499121896172069
# r2 score corresponding to: 55 is 0.5844051919099444
# r2 score corresponding to: 56 is 0.5868682429687004
# r2 score corresponding to: 57 is 0.6214944991770941
# r2 score corresponding to: 58 is 0.5161375228288814
# r2 score corresponding to: 59 is 0.5397128632230317
# ...

# %%
# Now we will use the cross_val_score to check the mean r2 score and standard deviation

print('Mean r2 score for Gradient boosting regression: ', cross_val_score(gbr,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for Gradient boosting regression:',cross_val_score(gbr,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for Gradient boosting regression:  0.5717226156615401
# Standard deviation in r2 score for Gradient boosting regression: 0.08880209056478193

# %%
# Now lets use adaboost regression algorithm

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
dtr=DecisionTreeRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000],'base_estimator':[lreg,lsreg,dtr]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 0.1,
#  'n_estimators': 500}

# %%
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(),learning_rate=0.1,n_estimators=500)
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2 score corresponding to: 42 is 0.5275053734048867
# r2 score corresponding to: 43 is 0.6059006841969499
# r2 score corresponding to: 44 is 0.6139757805790522
# r2 score corresponding to: 45 is 0.569226315239939
# r2 score corresponding to: 46 is 0.6233965471566872
# r2 score corresponding to: 47 is 0.6275012167334495
# r2 score corresponding to: 48 is 0.6387271135549023
# r2 score corresponding to: 49 is 0.5958442667526753
# r2 score corresponding to: 50 is 0.6660414673290209
# r2 score corresponding to: 51 is 0.6175533469348469
# r2 score corresponding to: 52 is 0.5677671377376141
# r2 score corresponding to: 53 is 0.6448960092092839
# r2 score corresponding to: 54 is 0.6869173858806037
# r2 score corresponding to: 55 is 0.6118085079411315
# r2 score corresponding to: 56 is 0.5781120180108743
# r2 score corresponding to: 57 is 0.5781765320794223
# r2 score corresponding to: 58 is 0.4865212222750327
# r2 score corresponding to: 59 is 0.5721530909632512
# ...

# %%
# Now we will use the cross_val_score to check the mean r2 score and standard deviation

print('Mean r2 score for Ada Boost regression: ', cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for Ada Boost regression:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for Ada Boost regression:  0.574151138604766
# Standard deviation in r2 score for Ada Boost regression: 0.07895375689097264

# %%
feat_importances = pd.Series(ada_reg.feature_importances_, index=x.columns)
feat_importances = feat_importances.nlargest(20)
feat_importances.plot(kind='barh')

# %% [raw]
# # factors or attributes which contribute the most towards acquatic toxicity towards fish (increased LC50 levels) in descending order are:
#
# # 1) MLOGP
# # 2) GATS1i
# # 3) SM1_Dz(Z)
# # 4) CIC0
# # 5) NDssC
# # 6) NDsCH

# %%
# We tried all the models and found that AdaBoost Regressor is the best
# Random state corresponding to highest r2 score is 84

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=94,test_size=0.20)
ada_reg=AdaBoostRegressor()
ada_reg.fit(x_train,y_train)
y_pred=ada_reg.predict(x_test)

# %%
# Lets find the rmse and r2 score using sklearn.metrics

import numpy as np

print('RMSE is:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2 score is:',r2_score(y_test,y_pred))
# Out:
# RMSE is: 0.9500636511841296
# r2 score is: 0.6051637076297889

# %%
from sklearn.externals import joblib

# Save the model as a pickle in a file

joblib.dump(ada_reg,'fishtoxicity.obj')
# Out:
# ['fishtoxicity.obj']

# %%
# load the model from the file

ada_reg_from_joblib=joblib.load('fishtoxicity.obj')

# Use the loaded model to make predictions

ada_reg_from_joblib.predict(x_test)
# Out:
# array([4.20950588, 3.14791864, 2.05781951, 4.09875785, 5.69004819,
#        4.37494286, 2.50437879, 3.36755161, 2.3225    , 4.20950588,
#        5.61742731, 3.14791864, 4.20950588, 4.1693966 , 2.98012299,
#        3.90333333, 3.05933159, 4.4974181 , 4.43384324, 4.51970787,
#        4.42913816, 4.43384324, 4.53601408, 6.07935714, 4.37494286,
#        3.15562667, 3.09830564, 5.53637838, 5.07237083, 4.56911111,
#        4.14363025, 3.77226761, 4.35018824, 3.05933159, 5.30445161,
#        5.3795    , 4.1693966 , 3.09830564, 4.14363025, 2.55436957,
#        4.14363025, 4.20950588, 4.14363025, 3.82295868, 4.1693966 ,
#        4.29859298, 2.77444262, 4.20950588, 4.41251282, 4.09875785,
#        4.1693966 , 4.56911111, 5.30445161, 3.09830564, 4.1693966 ,
#        6.19520755, 4.53601408, 4.9465    , 4.09875785, 3.14791864,
#        4.35018824, 6.25827933, 4.36375   , 4.1693966 , 4.35559434,
#        5.54148718, 3.68993939, 5.30445161, 4.5219291 , 4.51970787,
# ...
